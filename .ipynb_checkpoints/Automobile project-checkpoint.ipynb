# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Automobile Project

# %%
df = pd.read_csv("Automobile_data.csv")
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.isnull().sum() # i am  find null value in data set
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
df = df.dropna() # so we are useing dropna to remove null values

# %%
df.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df.shape
# Out:
# (58, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             58 non-null     int64
#  1   company           58 non-null     object
#  2   body-style        58 non-null     object
#  3   wheel-base        58 non-null     float64
#  4   length            58 non-null     float64
#  5   engine-type       58 non-null     object
#  6   num-of-cylinders  58 non-null     object
#  7   horsepower        58 non-null     int64
#  8   average-mileage   58 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.0+ KB

# %%
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
df.drop(['index'], axis=1, inplace = True)

# %% [markdown]
# # Q1. what is the average price and average mileage for convertible cars

# %%
avr_price_and_mileage = df.groupby(["body-style"])[["price","average-mileage"]].mean().loc[['convertible']]
avr_price_and_mileage
# Out:
#                price  average-mileage
# body-style
# convertible  22341.0        19.666667

# %% [markdown]
# # Q2. Sort cars by company and price in decending order

# %%
sort_cars = df.sort_values(by=['company','price'], ascending=False)
pd.DataFrame(sort_cars)
sort_cars
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 60          volvo        wagon       104.3   188.8         ohc
# 59          volvo        sedan       104.3   188.8         ohc
# 58     volkswagen        sedan        97.3   171.7         ohc
# 57     volkswagen        sedan        97.3   171.7         ohc
# 56     volkswagen        sedan        97.3   171.7         ohc
# 55     volkswagen        sedan        97.3   171.7         ohc
# 54         toyota        wagon       104.5   187.8        dohc
# 53         toyota        wagon        95.7   169.7         ohc
# 52         toyota        wagon        95.7   169.7         ohc
# 51         toyota        wagon        95.7   169.7         ohc
# 50         toyota    hatchback        95.7   158.7         ohc
# 49         toyota    hatchback        95.7   158.7         ohc
# 48         toyota    hatchback        95.7   158.7         ohc
# 46        porsche  convertible        89.5   168.9        ohcf
# ...

# %% [markdown]
# # Q3. Save data for 'Toyota' separately

# %% [markdown]
# # Q4. which company is producing most expensive car?

# %%
most = df.groupby(['company'])["price"].sum()

# %%
most_expensive_car = most.nlargest(1)
most_expensive_car = pd.DataFrame(most_expensive_car)
most_expensive_car
# Out:
#             price
# company
# bmw      163280.0

# %% [markdown]
# # Q5. Name the cars on basis of maximum length, highest wheelbase, maximum horsepower

# %%
max_cars = df.groupby(['company'])[['length','wheel-base','horsepower']].max().sort_values(by =['length','wheel-base','horsepower'],ascending=False)

# %%
max_cars
# Out:
#                length  wheel-base  horsepower
# company
# mercedes-benz   208.1       120.9         184
# jaguar          199.6       113.0         262
# bmw             197.0       110.0         182
# audi            192.7       105.8         115
# volvo           188.8       104.3         114
# toyota          187.8       104.5         156
# nissan          184.6       100.4         152
# porsche         175.7        98.4         288
# honda           175.4        96.5         101
# mazda           175.0       104.9         101
# mitsubishi      172.4        96.3          88
# volkswagen      171.7        97.3         100
# alfa-romero     171.2        94.5         154
# isuzu           170.7        94.5          78
# chevrolet       158.8        94.5          70
# dodge           157.3        93.7          68

# %% [markdown]
# # Q6. company wise average price of cars and order them in decending order

# %%
aver_price_cars = df.groupby(['company'])['price'].mean().sort_values(ascending=False).round(decimals=2)
aver_price_cars = pd.DataFrame(aver_price_cars)
aver_price_cars
# Out:
#                   price
# company
# porsche        35528.00
# mercedes-benz  35040.00
# jaguar         34600.00
# bmw            27213.33
# audi           16392.50
# alfa-romero    15498.33
# volvo          13177.50
# honda          10195.00
# mazda           9654.80
# volkswagen      8435.00
# nissan          8289.00
# toyota          8216.86
# isuzu           6785.00
# mitsubishi      6689.00
# dodge           6303.00
# chevrolet       6007.00

# %% [markdown]
# # Q7. create a column named: "decision", If wheel-base is less than 100 and length is less than 175 then "don't buy" else "buy"

# %%
df['decision'] = np.where((df['wheel-base'] < 100) & (df['length'] < 175), "don't buy", "buy")
# Out:
# C:\Users\Ahil Quazi\AppData\Local\Temp\ipykernel_14680\4062340535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decision'] = np.where((df['wheel-base'] < 100) & (df['length'] < 175), "don't buy", "buy")

# %%
decision = df
decision
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 0     alfa-romero  convertible        88.6   168.8        dohc
# 1     alfa-romero  convertible        88.6   168.8        dohc
# 2     alfa-romero    hatchback        94.5   171.2        ohcv
# 3            audi        sedan        99.8   176.6         ohc
# 4            audi        sedan        99.4   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 7             bmw        sedan       101.2   176.8         ohc
# 8             bmw        sedan       101.2   176.8         ohc
# 9             bmw        sedan       101.2   176.8         ohc
# 10            bmw        sedan       103.5   189.0         ohc
# 11            bmw        sedan       103.5   193.8         ohc
# 12            bmw        sedan       110.0   197.0         ohc
# 13      chevrolet    hatchback        88.4   141.1           l
# ...

# %% [markdown]
# # Q8. Select only cars whose decision is "buy"; find average price based on company of car

# %%
average_price_by_company = df[df['decision'] == 'buy'].groupby('company')['price'].mean()
average_price_by_company = pd.DataFrame(average_price_by_company)
average_price_by_company
# Out:
#                       price
# company
# audi           16392.500000
# bmw            27213.333333
# honda          12945.000000
# jaguar         34600.000000
# mazda          18344.000000
# mercedes-benz  35040.000000
# nissan         13499.000000
# toyota         15750.000000
# volvo          13177.500000

# %%
writer = pd.ExcelWriter("Automobile_Output_File.xlsx")

avr_price_and_mileage.to_excel(writer, sheet_name='avr_price_and_mileage')
sort_cars.to_excel(writer, sheet_name='sort_cars_by_company_and_price',index=False)
most_expensive_car.to_excel(writer, sheet_name='most_expensive_car')
max_cars.to_excel(writer, sheet_name='max_cars')
aver_price_cars.to_excel(writer, sheet_name='aver_price_cars')
decision.to_excel(writer, sheet_name='decision',index=False)
average_price_by_company.to_excel(writer, sheet_name='average_price_by_company')

writer.close() # The save() method has been deprecated and removed in Pandas. You should use close() instead.
